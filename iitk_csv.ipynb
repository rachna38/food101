# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('iitk_course.csv')

# %%
df
# Out:
#          Student Name  Course  Marks (%)  Attendance (%)
# 0         Dipon Konar  ELC111      56.72           63.08
# 1      Parth Parashar  PHY113      84.59           20.96
# 2         Anurag Sahu  MTH113      41.13           59.86
# 3    Hemakshi Kumawat  CHM112      59.43           57.34
# 4      Parth Parashar  ELC111      62.88           30.82
# ..                ...     ...        ...             ...
# 195     Kritika Singh  ELC112      68.57           77.98
# 196   Harshit Karnani  PHY112      52.31           35.75
# 197       Sneha Patra  PHY113      58.98           21.98
# 198       Ashma Singh  PHY111      88.56           82.63
# 199    Parth Parashar  PHY115      80.52           42.89
#
# [200 rows x 4 columns]

# %%
print(df.to_string())
# Out:
#            Student Name  Course  Marks (%)  Attendance (%)
# 0           Dipon Konar  ELC111      56.72           63.08
# 1        Parth Parashar  PHY113      84.59           20.96
# 2           Anurag Sahu  MTH113      41.13           59.86
# 3      Hemakshi Kumawat  CHM112      59.43           57.34
# 4        Parth Parashar  ELC111      62.88           30.82
# 5      Nikhil Prajapati  LIF111      50.92           84.25
# 6          Prince Singh  MTH111      66.27             NaN
# 7           Gungun Jain  PHY111      57.53           42.08
# 8      Nikhil Prajapati  ELC112      74.09           58.68
# 9              Siva Sai  PHY111      84.92           53.99
# 10       Manisha Rathod  PHY114      62.63           69.32
# 11     Hemakshi Kumawat  CHM113      80.87           34.85
# 12         Pratik Maity  CHM111        NaN           66.10
# 13   Praneel iralapalle  PHY115      65.80           61.74
# 14             Siva Sai  ELC113      56.81           66.56
# ...

# %%
print(df.isnull())
# Out:
#      Student Name  Course  Marks (%)  Attendance (%)
# 0           False   False      False           False
# 1           False   False      False           False
# 2           False   False      False           False
# 3           False   False      False           False
# 4           False   False      False           False
# ..            ...     ...        ...             ...
# 195         False   False      False           False
# 196         False   False      False           False
# 197         False   False      False           False
# 198         False   False      False           False
# 199         False   False      False           False
#
# [200 rows x 4 columns]

# %%
new_df = df.dropna(subset=['Student Name'])

# %%
print(new_df)
# Out:
#          Student Name  Course  Marks (%)  Attendance (%)
# 0         Dipon Konar  ELC111      56.72           63.08
# 1      Parth Parashar  PHY113      84.59           20.96
# 2         Anurag Sahu  MTH113      41.13           59.86
# 3    Hemakshi Kumawat  CHM112      59.43           57.34
# 4      Parth Parashar  ELC111      62.88           30.82
# ..                ...     ...        ...             ...
# 195     Kritika Singh  ELC112      68.57           77.98
# 196   Harshit Karnani  PHY112      52.31           35.75
# 197       Sneha Patra  PHY113      58.98           21.98
# 198       Ashma Singh  PHY111      88.56           82.63
# 199    Parth Parashar  PHY115      80.52           42.89
#
# [188 rows x 4 columns]

# %%
numerical_columns = ['Marks (%)','Attendence (%)']

# %%
def geometric_mean(a, b):
    if a > 0 and b > 0:  
        return np.sqrt(a * b)
    return np.nan

# %%
for column in numerical_columns:
    for i in range(1, len(new_df) - 1):  
        if pd.isnull(new_df[column].iloc[i]): 
            previous_value = bew_df[column].iloc[i - 1]
            next_value = new_df[column].iloc[i + 1]
            
            new_df[column].iloc[i] = geometric_mean(previous_value, next_value)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\python13\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Marks'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 3
#       1 for column in numerical_columns:
# ...

# %%
new_df.to_csv('cleaned_IITK_Courses_Report.csv')
